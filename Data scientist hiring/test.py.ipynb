#  'Provider~79,287,117,35~99~1~2\r',
#  'No.~205,287,49,35~91~1~2\r',
#  '298479BY~263,287,147,35~97~1~2\r',
#  'David~79,363,80,35~95~1~3\r',
#  'Lopis~168,363,75,35~95~1~3\r',
#  'Provider~79,402,117,35~100~1~4\r',
#  'No.~205,402,49,35~91~1~4\r',
#  '5142323B~263,402,143,35~90~1~4\r',
#  'Invoice~99,491,80,26~97~1~5\r',
#  '143014741~185,491,116,26~97~1~5\r',
#  'Invoice~836,491,80,26~95~1~5\r',
#  'Date~922,491,50,26~98~1~5\r',
#  ':~979,491,7,26~96~1~5\r',
#  '07-Dec-2019~993,491,135,26~97~1~5\r',
#  'Practitioner~99,564,129,26~93~1~6\r',
#  'Patient~855,567,77,26~97~1~6\r',
#  'Name~99,604,57,24~99~1~7\r',
#  'Ms~328,604,28,24~92~1~7\r',
#  'Jodie~363,604,51,24~97~1~7\r',
#  'Wassner~421,604,85,24~97~1~7\r',
#  'Name~855,607,57,24~98~1~7\r',
#  'Ms~1085,607,28,24~100~1~7\r',
#  'Emma~1120,607,62,24~96~1~7\r',
#  'Lewkovitz~1188,607,94,24~97~1~7\r',
#  'Address~99,645,79,24~98~1~8\r',
# ...

# %%
for i, line in enumerate(a):
    print(line)
    text, coor, score, page,lno = line.split('~')
# Out:
# Jodie~79,249,75,35~98~1~1
# Wassner~163,249,124,35~99~1~1
# Provider~79,287,117,35~99~1~2
# No.~205,287,49,35~91~1~2
# 298479BY~263,287,147,35~97~1~2
# David~79,363,80,35~95~1~3
# Lopis~168,363,75,35~95~1~3
# Provider~79,402,117,35~100~1~4
# No.~205,402,49,35~91~1~4
# 5142323B~263,402,143,35~90~1~4
# Invoice~99,491,80,26~97~1~5
# 143014741~185,491,116,26~97~1~5
# Invoice~836,491,80,26~95~1~5
# Date~922,491,50,26~98~1~5
# :~979,491,7,26~96~1~5
# 07-Dec-2019~993,491,135,26~97~1~5
# Practitioner~99,564,129,26~93~1~6
# Patient~855,567,77,26~97~1~6
# Name~99,604,57,24~99~1~7
# Ms~328,604,28,24~92~1~7
# Jodie~363,604,51,24~97~1~7
# Wassner~421,604,85,24~97~1~7
# Name~855,607,57,24~98~1~7
# Ms~1085,607,28,24~100~1~7
# Emma~1120,607,62,24~96~1~7
# Lewkovitz~1188,607,94,24~97~1~7
# Address~99,645,79,24~98~1~8
# Curious~328,645,74,24~95~1~8
# Kids~409,645,41,24~96~1~8
# Psychology~457,645,110,24~97~1~8
# Address~855,649,79,24~92~1~8
# 43~1085,649,23,24~91~1~8
# Balfour~1115,649,68,24~99~1~8
# ...
